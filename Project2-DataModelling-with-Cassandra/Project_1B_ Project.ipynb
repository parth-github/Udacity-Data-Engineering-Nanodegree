# %% [markdown]
# # Part I. ETL Pipeline for Pre-Processing the Files

# %% [markdown]
# ## PLEASE RUN THE FOLLOWING CODE FOR PRE-PROCESSING THE FILES

# %% [markdown]
# #### Import Python packages

# %%
# Import Python packages 
import pandas as pd
import cassandra
import re
import os
import glob
import numpy as np
import json
import csv

# %% [markdown]
# #### Creating list of filepaths to process original event csv data files

# %%
# checking your current working directory
print(os.getcwd())

# Get your current folder and subfolder event data
filepath = os.getcwd() + '/event_data'

# Create a for loop to create a list of files and collect each filepath
for root, dirs, files in os.walk(filepath):
    
# join the file path and roots with the subdirectories using glob
    file_path_list = glob.glob(os.path.join(root,'*'))
    #print(file_path_list)
# Out:
# /home/workspace

# %% [markdown]
# #### Processing the files to create the data file csv that will be used for Apache Casssandra tables

# %%
# initiating an empty list of rows that will be generated from each file
full_data_rows_list = [] 
    
# for every filepath in the file path list 
for f in file_path_list:

# reading csv file 
    with open(f, 'r', encoding = 'utf8', newline='') as csvfile: 
        # creating a csv reader object 
        csvreader = csv.reader(csvfile) 
        next(csvreader)
        
 # extracting each data row one by one and append it        
        for line in csvreader:
            #print(line)
            full_data_rows_list.append(line) 
            
# uncomment the code below if you would like to get total number of rows 
#print(len(full_data_rows_list))
# uncomment the code below if you would like to check to see what the list of event data rows will look like
#print(full_data_rows_list)

# creating a smaller event data csv file called event_datafile_full csv that will be used to insert data into the \
# Apache Cassandra tables
csv.register_dialect('myDialect', quoting=csv.QUOTE_ALL, skipinitialspace=True)

with open('event_datafile_new.csv', 'w', encoding = 'utf8', newline='') as f:
    writer = csv.writer(f, dialect='myDialect')
    writer.writerow(['artist','firstName','gender','itemInSession','lastName','length',\
                'level','location','sessionId','song','userId'])
    for row in full_data_rows_list:
        if (row[0] == ''):
            continue
        writer.writerow((row[0], row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[12], row[13], row[16]))

# %%
# check the number of rows in your csv file
with open('event_datafile_new.csv', 'r', encoding = 'utf8') as f:
    print(sum(1 for line in f))
# Out:
# 6821

# %% [markdown]
# # Part II. Complete the Apache Cassandra coding portion of your project.
#
# ## Now you are ready to work with the CSV file titled <font color=red>event_datafile_new.csv</font>, located within the Workspace directory.  The event_datafile_new.csv contains the following columns:
# - artist
# - firstName of user
# - gender of user
# - item number in session
# - last name of user
# - length of the song
# - level (paid or free song)
# - location of the user
# - sessionId
# - song title
# - userId
#
# The image below is a screenshot of what the denormalized data should appear like in the <font color=red>**event_datafile_new.csv**</font> after the code above is run:<br>
#
# <img src="images/image_event_datafile_new.jpg">

# %% [markdown]
# ## Begin writing your Apache Cassandra code in the cells below

# %% [markdown]
# #### Creating a Cluster

# %%
# This should make a connection to a Cassandra instance your local machine 
# (127.0.0.1)

from cassandra.cluster import Cluster
cluster = Cluster(['127.0.0.1'])

# To establish connection and begin executing queries, need a session
session = cluster.connect()

# %% [markdown]
# #### Create Keyspace

# %%
# TO-DO: Create a Keyspace 
try:
    session.execute("""
    CREATE KEYSPACE IF NOT EXISTS sparkifydb 
    WITH REPLICATION = 
    { 'class' : 'SimpleStrategy', 'replication_factor' : 1 }"""
)

except Exception as e:
    print(e)

# %% [markdown]
# #### Set Keyspace

# %%
# TO-DO: Set KEYSPACE to the keyspace specified above
try:
    session.set_keyspace('sparkifydb')
except Exception as e:
    print(e)

# %% [markdown]
# ### Now we need to create tables to run the following queries. Remember, with Apache Cassandra you model the database tables on the queries you want to run.

# %% [markdown]
# ## Create queries to ask the following three questions of the data
#
# ### 1. Give me the artist, song title and song's length in the music app history that was heard during  sessionId = 338, and itemInSession  = 4
#
#
# ### 2. Give me only the following: name of artist, song (sorted by itemInSession) and user (first and last name) for userid = 10, sessionid = 182
#
#
# ### 3. Give me every user name (first and last) in my music app history who listened to the song 'All Hands Against His Own'

# %%
## TO-DO: Query 1:  Give me the artist, song title and song's length in the music app history that was heard during \
## sessionId = 338, and itemInSession = 4
query = "CREATE TABLE IF NOT EXISTS song_details "
query = query + "(sessionId INT, itemInSession INT, artist TEXT, song TEXT, length FLOAT, PRIMARY KEY (sessionId, itemInSession))"
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
# We have provided part of the code to set up the CSV file. Please complete the Apache Cassandra code below#
file = 'event_datafile_new.csv'

with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader) # skip header
    for line in csvreader:
## TO-DO: Assign the INSERT statements into the `query` variable
        query = "INSERT INTO song_details(sessionId, itemInSession, artist, song, length)"
        query = query + "VALUES (%s, %s, %s, %s, %s)"
        ## TO-DO: Assign which column element should be assigned for each column in the INSERT statement.
        ## For e.g., to INSERT artist_name and user first_name, you would change the code below to `line[0], line[1]`
        session.execute(query, (int(line[8]), int(line[3]), line[0], line[9], float(line[5])))

# %% [markdown]
# #### Do a SELECT to verify that the data have been inserted into each table

# %%
## TO-DO: Add in the SELECT statement to verify the data was entered into the table
select_query_1 = """ SELECT artist, song, length FROM song_details
                    WHERE sessionId = %s 
                    AND itemInSession = %s 
                    """

try:
    rows = session.execute(select_query_1, (338, 4))
    
    for row in rows:
        print("Artist: "+row.artist, "\nSong Title: "+row.song, "\nSong Length: "+str(row.length))
    
except Exception as e:
    print(e)
# Out:
# Artist: Faithless
# Song Title: Music Matters (Mark Knight Dub)
# Song Length: 495.30731201171875

# %% [markdown]
# ### COPY AND REPEAT THE ABOVE THREE CELLS FOR EACH OF THE THREE QUESTIONS

# %%
## TO-DO: Query 2: Give me only the following: name of artist, song (sorted by itemInSession) and user (first and last name)\
## for userid = 10, sessionid = 182

query = "CREATE TABLE IF NOT EXISTS aritst_details "
query = query + "(sessionId INT, userid INT, itemInSession INT, artist TEXT, song TEXT, firstName TEXT, lastName TEXT, PRIMARY KEY (sessionId, userid))"
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
# We have provided part of the code to set up the CSV file. Please complete the Apache Cassandra code below#
file = 'event_datafile_new.csv'

with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader) # skip header
    for line in csvreader:
        #print(line)
## TO-DO: Assign the INSERT statements into the `query` variable
        query = "INSERT INTO aritst_details(sessionId, userid, itemInSession, artist, song, firstName, lastName)"
        query = query + "VALUES (%s, %s, %s, %s, %s, %s, %s)"
        #print(int(line[8]), int(line[10]), int(line[3]), line[0], line[9], line[1], line[4])
        ## TO-DO: Assign which column element should be assigned for each column in the INSERT statement.
        ## For e.g., to INSERT artist_name and user first_name, you would change the code below to `line[0], line[1]`
        session.execute(query, (int(line[8]), int(line[10]), int(line[3]), line[0], line[9], line[1], line[4]))

# %%
## TO-DO: Add in the SELECT statement to verify the data was entered into the table        
select_query_2 = """ SELECT artist, song, firstName, lastName
                    FROM aritst_details
                    WHERE sessionId = %s 
                    AND userid = %s 
                    """

try:
    rows = session.execute(select_query_2, (182, 10))
    
    for row in rows:
        print("Artist: "+row.artist, "\nSong Title: "+row.song, "\nUser First Name: "+str(row.firstname), "\nUser Last Name: "+str(row.lastname))
    
except Exception as e:
    print(e)
# Out:
# Artist: Lonnie Gordon
# Song Title: Catch You Baby (Steve Pitron & Max Sanna Radio Edit)
# User First Name: Sylvie
# User Last Name: Cruz

# %%
## TO-DO: Query 3: Give me every user name (first and last) in my music app history who listened to the song 'All Hands Against His Own'

query = "CREATE TABLE IF NOT EXISTS user_details "
query = query + "(song TEXT, userid INT, firstName TEXT, lastName TEXT, PRIMARY KEY ((song), userid))"
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
# We have provided part of the code to set up the CSV file. Please complete the Apache Cassandra code below#
file = 'event_datafile_new.csv'

with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader) # skip header
    for line in csvreader:
        #print(line)
## TO-DO: Assign the INSERT statements into the `query` variable
        query = "INSERT INTO user_details(song, userid, firstname, lastname)"
        query = query + "VALUES (%s, %s, %s, %s)"
        #print(line[9],':', int(line[10]), line[1],'-', line[4])
        ## TO-DO: Assign which column element should be assigned for each column in the INSERT statement.
        ## For e.g., to INSERT artist_name and user first_name, you would change the code below to `line[0], line[1]`
        session.execute(query, (line[9], int(line[10]), line[1], line[4]))
# Out:
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile) : 88 Mohammad - Rodriguez
# Woodstock Inprovisation : 88 Mohammad - Rodriguez
# Majesty (LP Version) : 88 Mohammad - Rodriguez
# Love Shack : 38 Gianna - Jones
# Frisch und g'sund : 38 Gianna - Jones
# Look At Me : 38 Gianna - Jones
# Ya EntendÃÂ­ : 8 Kaylee - Summers
# All Tomorrow's Parties : 8 Kaylee - Summers
# Psst! : 8 Kaylee - Summers
# There's Your Trouble : 8 Kaylee - Summers
# Given Up (Album Version) : 8 Kaylee - Summers
# Take Her Out : 66 Kevin - Arellano
# My Boy Builds Coffins : 69 Anabelle - Simpson
# The Mystery Zone : 52 Theodore - Smith
# Would? : 86 Aiden - Hess
# Colorblind : 86 Aiden - Hess
# End Of The Line : 50 Ava - Robinson
# Relax : 49 Chloe - Cuevas
# The Decline : 49 Chloe - Cuevas
# Word Up! : 49 Chloe - Cuevas
# Look Outside : 24 Layla - Griffin
# Won't Do : 24 Layla - Griffin
# Never Gonna Let You Go : 24 Layla - Griffin
# En Lo Puro No Hay Futuro : 24 Layla - Griffin
# I Told You So : 24 Layla - Griffin
# Je T'aime Till My Dying Day : 5 Elijah - Davis
# The Trouble With Love Is : 24 Layla - Griffin
# Put 'Em On : 24 Layla - Griffin
# Tales of Girls_ Boys and Marsupials (album version) : 5 Elijah - Davis
# Macrotus : 49 Chloe - Cuevas
# Scarborough Fair : 36 Matthew - Jones
# Hello Sunshine : 36 Matthew - Jones
# Supermassive Black Hole (Twilight Soundtrack Version) : 49 Chloe - Cuevas
# Shiver : 36 Matthew - Jones
# Tears In Heaven : 49 Chloe - Cuevas
# What If (Film Version) : 36 Matthew - Jones
# The Enemy (Album Version) : 49 Chloe - Cuevas
# Punch Drunk Grinning Soul : 36 Matthew - Jones
# Quutamo : 49 Chloe - Cuevas
# Mouthful Of Cavities : 36 Matthew - Jones
# In A Dead World (Album Version) : 49 Chloe - Cuevas
# Let It Out : 36 Matthew - Jones
# Let's Get It Started : 49 Chloe - Cuevas
# Don't Panic : 36 Matthew - Jones
# The Power of Orange Knickers : 36 Matthew - Jones
# Summer Night City : 36 Matthew - Jones
# Hit 'Em Up Style (Oops!) : 36 Matthew - Jones
# Let It Go : 36 Matthew - Jones
# Can't Stop : 36 Matthew - Jones
# The Gift : 36 Matthew - Jones
# Lazy Eye [Jason Bentley Remix] : 36 Matthew - Jones
# Drove Through Ghosts to Get Here : 88 Mohammad - Rodriguez
# Se Me OlvidÃÂ³ Que Te OlvidÃÂ© : 36 Matthew - Jones
# Soul Of A Vagabond : 36 Matthew - Jones
# BedRock (Radio Edit) (feat.Lloyd) : 88 Mohammad - Rodriguez
# (Keep Feeling) Fascination (2003 Digital Remaster) : 88 Mohammad - Rodriguez
# Aldebaran : 36 Matthew - Jones
# Eu Te Amo : 88 Mohammad - Rodriguez
# In The House Of Tom Bombadil : 36 Matthew - Jones
# Crawling (Album Version) : 28 Brantley - West
# King Without A Crown : 88 Mohammad - Rodriguez
# Wotan's Farewell & Magic Fire Music : 36 Matthew - Jones
# Someone To Share My Life With : 88 Mohammad - Rodriguez
# Take California : 88 Mohammad - Rodriguez
# Human After All (SebastiAn Remix ) : 80 Tegan - Levine
# Home : 88 Mohammad - Rodriguez
# I Want You Now : 80 Tegan - Levine
# Untrust us : 88 Mohammad - Rodriguez
# Busted : 80 Tegan - Levine
# The Way I Are : 36 Matthew - Jones
# Nascita Of The Monsters : 88 Mohammad - Rodriguez
# Lullaby [With Ladysmith Black Mambazo] (Album Version) : 80 Tegan - Levine
# Hers is the twilight : 36 Matthew - Jones
# ReprÃÂ©sente : 80 Tegan - Levine
# Tomorrow : 80 Tegan - Levine
# Don't Ask : 36 Matthew - Jones
# Let's Work : 36 Matthew - Jones
# Arguru : 88 Mohammad - Rodriguez
# Yeah! : 88 Mohammad - Rodriguez
# Learn to Talk : 36 Matthew - Jones
# Por Amarte AsÃÂ­ : 88 Mohammad - Rodriguez
# Undo : 36 Matthew - Jones
# Probably Wouldn't Be This Way (Dann Huff remix) : 88 Mohammad - Rodriguez
# Addicted To Your Love : 36 Matthew - Jones
# Rock The House (Radio Edit) : 80 Tegan - Levine
# Used To Love Her : 88 Mohammad - Rodriguez
# Phantastica : 36 Matthew - Jones
# Soldier : 80 Tegan - Levine
# Relief Next To Me (Album Version) : 88 Mohammad - Rodriguez
# Undo : 36 Matthew - Jones
# Thank You for Being a Friend : 80 Tegan - Levine
# Imanol : 88 Mohammad - Rodriguez
# Welcome To The Black Parade (Album Version) : 77 Magdalene - Herman
# Somebody To Love : 88 Mohammad - Rodriguez
# Aanzoek Zonder Ringen (met Kodo) : 80 Tegan - Levine
# Bat Country (Album Version) : 36 Matthew - Jones
# I Feel So Fine  : 88 Mohammad - Rodriguez
# Revelry : 77 Magdalene - Herman
# Midlife Crisis : 80 Tegan - Levine
# Him : 36 Matthew - Jones
# Alone In This Bed (Capeside) : 77 Magdalene - Herman
# Brave as a Noun : 36 Matthew - Jones
# Girl Tonite [Featuring Trey Songz] [Explicit Album Version] : 80 Tegan - Levine
# Thong Song : 88 Mohammad - Rodriguez
# To Heal : 77 Magdalene - Herman
# The Only Exception (Album Version) : 36 Matthew - Jones
# Hey_ Soul Sister : 77 Magdalene - Herman
# Frisch und g'sund : 80 Tegan - Levine
# I CAN'T GET STARTED : 88 Mohammad - Rodriguez
# Undantag : 36 Matthew - Jones
# Pursuit Of Happiness (nightmare) : 77 Magdalene - Herman
# Viejo : 36 Matthew - Jones
# Y solo se me ocurre amarte (Unplugged) : 88 Mohammad - Rodriguez
# Burn My Shadow : 36 Matthew - Jones
# My Love : 88 Mohammad - Rodriguez
# Take It All : 55 Martin - Johnson
# Where Is My Mind? : 36 Matthew - Jones
# Last Cup Of Sorrow : 88 Mohammad - Rodriguez
# Rocky : 36 Matthew - Jones
# I Believe In A Thing Called Love : 88 Mohammad - Rodriguez
# Mais E Mais Amor : 36 Matthew - Jones
# Flava In Your Ear : 88 Mohammad - Rodriguez
# Grux : 80 Tegan - Levine
# Soulful Dress : 80 Tegan - Levine
# Orange TrÃÂ¤gt Nur Die MÃÂ¼llabfuhr (Go West) : 88 Mohammad - Rodriguez
# Frases Mudas : 80 Tegan - Levine
# Gong : 88 Mohammad - Rodriguez
# You Are Not Stubborn : 80 Tegan - Levine
# Firecracker : 80 Tegan - Levine
# Sin Salsa No Hay ParaÃÂ­so : 88 Mohammad - Rodriguez
# Heavy Soul  : 80 Tegan - Levine
# Yes Please : 88 Mohammad - Rodriguez
# The World We Love So Much : 80 Tegan - Levine
# Van Helsing Boombox : 88 Mohammad - Rodriguez
# Untangle : 80 Tegan - Levine
# OMG : 88 Mohammad - Rodriguez
# Peggy-O [Studio Outtake] : 80 Tegan - Levine
# I Never (Album Version) : 88 Mohammad - Rodriguez
# I'm Your Man : 80 Tegan - Levine
# Love Me : 88 Mohammad - Rodriguez
# Miss You : 80 Tegan - Levine
# Addicted2Me : 88 Mohammad - Rodriguez
# A Man/Me/Then Jim (Album Version) : 88 Mohammad - Rodriguez
# Cosmic Love : 80 Tegan - Levine
# Harder Better Faster Stronger (Alive Radio Edit 2007) : 80 Tegan - Levine
# Your Body's Callin' : 37 Jordan - Hicks
# Fall In Love (your funeral) : 80 Tegan - Levine
# Sweets For My Sweet : 37 Jordan - Hicks
# Here It Comes : 80 Tegan - Levine
# Mrs. Officer : 80 Tegan - Levine
# Becoming [Live Version] : 80 Tegan - Levine
# DOA : 80 Tegan - Levine
# My Ride : 80 Tegan - Levine
# Fireflies : 80 Tegan - Levine
# Breed : 80 Tegan - Levine
# Stronger : 80 Tegan - Levine
# The New Chapter : 80 Tegan - Levine
# Love Is All Around : 80 Tegan - Levine
# Come Fly With Me (Album Version) : 80 Tegan - Levine
# To Ever Live Without Me : 80 Tegan - Levine
# Please Don't Go : 80 Tegan - Levine
# Postcards From Far Away : 61 Samuel - Gonzalez
# Crumpshit : 61 Samuel - Gonzalez
# Intro : 80 Tegan - Levine
# Method Man : 80 Tegan - Levine
# Love & Leaving : 61 Samuel - Gonzalez
# What Have I Done To Deserve This? (2001 Digital Remaster) : 80 Tegan - Levine
# The Only Exception (Album Version) : 61 Samuel - Gonzalez
# We Are One : 80 Tegan - Levine
# Cause You Know : 61 Samuel - Gonzalez
# Hip-Hop Saved My Life (feat. Nikki Jean) (Explicit Album Version) : 80 Tegan - Levine
# If Not For Your Grace : 80 Tegan - Levine
# Bird Song Intro : 61 Samuel - Gonzalez
# Actions not words : 80 Tegan - Levine
# Happy Up Here : 80 Tegan - Levine
# In One Ear : 80 Tegan - Levine
# There Are Worse Things Than Being Alone : 80 Tegan - Levine
# La Pared : 80 Tegan - Levine
# Fight Fire With Fire : 80 Tegan - Levine
# red signal : 32 Lily - Burns
# Just Another Day : 80 Tegan - Levine
# Baobabs (Bonus Album Version) : 80 Tegan - Levine
# Sala De RecepÃÂ§ÃÂ£o : 80 Tegan - Levine
# Not the One (Album Version) : 80 Tegan - Levine
# Lithium : 80 Tegan - Levine
# Where Damage Isn't Already Done : 80 Tegan - Levine
# Con sÃÂ³lo una mirada : 80 Tegan - Levine
# Alejandro : 80 Tegan - Levine
# Fools : 80 Tegan - Levine
# Go To Sleep : 80 Tegan - Levine
# Mean Ol'World : 99 Ann - Banks
# En Mi Mundo : 43 Jahiem - Miles
# We'll Never Know : 43 Jahiem - Miles
# Cabaret Blanco : 43 Jahiem - Miles
# Tarkus : 6 Cecilia - Owens
# Weird Era : 25 Jayden - Graves
# No Surprise : 25 Jayden - Graves
# Club Tropicana : 25 Jayden - Graves
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile) : 25 Jayden - Graves
# Depot Blues : 25 Jayden - Graves
# Lucky (Album Version) : 25 Jayden - Graves
# Talking In Your Sleep : 25 Jayden - Graves
# Such Great Heights : 25 Jayden - Graves
# Always Will (LP Version) : 25 Jayden - Graves
# Above The Clouds (Edited) : 25 Jayden - Graves
# Coldest Winter : 25 Jayden - Graves
# Nan Ni Wan : 25 Jayden - Graves
# Back In The Day : 25 Jayden - Graves
# Vielas De Alfama : 51 Maia - Burke
# Epilogue : 25 Jayden - Graves
# Non E_ Per Te_ Per Me : 51 Maia - Burke
# Fight For Your Life : 25 Jayden - Graves
# ReprÃÂ©sente : 25 Jayden - Graves
# Run_ Don't Walk : 25 Jayden - Graves
# The Door : 25 Jayden - Graves
# Love Always : 25 Jayden - Graves
# Red Elephant : 26 Ryan - Smith
# Your Decision : 80 Tegan - Levine
# Stripes : 36 Matthew - Jones
# Bleed It Out [Live At Milton Keynes] : 18 Jacob - Rogers
# Ain't Misbehavin : 26 Ryan - Smith
# Every Shining Time You Arrive (Album) : 36 Matthew - Jones
# I'm Shady : 80 Tegan - Levine
# Call 9-1-1 (Explicit) : 36 Matthew - Jones
# Remember Me_ I'm The One Who Loves You : 36 Matthew - Jones
# It Just Don't Stop : 36 Matthew - Jones
# El Cuatrero : 36 Matthew - Jones
# All Along The Watchtower : 36 Matthew - Jones
# Kalidafun Parts 1&2 : 36 Matthew - Jones
# Rosemary : 36 Matthew - Jones
# Blue Collar Man (Long Nights) : 36 Matthew - Jones
# Su veneno : 36 Matthew - Jones
# Hot N Cold (Manhattan Clique Remix Radio Edit) : 36 Matthew - Jones
# Bebot : 36 Matthew - Jones
# Lava Lava : 36 Matthew - Jones
# Air & Lack Thereof : 36 Matthew - Jones
# My Mamma Said : 80 Tegan - Levine
# Piano Concerto No. 2 in G minor Op. 22 (2006 Digital Remaster): III.  Presto : 36 Matthew - Jones
# Where Is My Mind? : 80 Tegan - Levine
# Drunk Girls : 80 Tegan - Levine
# Two Hearts : 36 Matthew - Jones
# Reptilia : 36 Matthew - Jones
# Clockwork Skinhead : 85 Kinsley - Young
# Scream For More : 36 Matthew - Jones
# God's Plan : 85 Kinsley - Young
# Kiss It Better : 85 Kinsley - Young
# All Of The Champs That Ever Lived : 36 Matthew - Jones
# Something : 36 Matthew - Jones
# Fireflies : 36 Matthew - Jones
# English Summer Rain : 36 Matthew - Jones
# Man/Bag Of Sand : 36 Matthew - Jones
# Don't Think I Don't Think About It : 36 Matthew - Jones
# Everlong : 36 Matthew - Jones
# Transparency : 49 Chloe - Cuevas
# Jambalaya (On The Bayou) : 36 Matthew - Jones
# I CAN'T GET STARTED : 49 Chloe - Cuevas
# Te Amo : 36 Matthew - Jones
# Kellum (Album Version) : 36 Matthew - Jones
# My All : 36 Matthew - Jones
# Change Is Hard : 49 Chloe - Cuevas
# Sugar (Jagz Kooner Mix) : 49 Chloe - Cuevas
# Dumb Blood : 36 Matthew - Jones
# Time Bomb : 36 Matthew - Jones
# In The Closet : 36 Matthew - Jones
# Don't Go : 36 Matthew - Jones
# BedRock (Radio Edit) (feat.Lloyd) : 36 Matthew - Jones
# Rock With Me : 36 Matthew - Jones
# Motor Panir : 36 Matthew - Jones
# Right Through You (LP Version) : 36 Matthew - Jones
# Supermassive Black Hole (Twilight Soundtrack Version) : 36 Matthew - Jones
# Brackett_ WI : 36 Matthew - Jones
# Burn Them Prisons : 36 Matthew - Jones
# Mighty K.C. : 36 Matthew - Jones
# Tu Me Asustas : 36 Matthew - Jones
# Barbwire : 36 Matthew - Jones
# Ante Up (Robbin Hoodz Theory) : 36 Matthew - Jones
# Crack A Bottle : 36 Matthew - Jones
# Estoy AquÃÂ­ : 53 Celeste - Williams
# Yeah! : 36 Matthew - Jones
# Hanuman : 36 Matthew - Jones
# I Wanna Be Sedated (Remastered Album Version ) : 36 Matthew - Jones
# Miserable At Best (Album) : 36 Matthew - Jones
# Music Box : 25 Jayden - Graves
# Visions : 25 Jayden - Graves
# Calyx Virago : 14 Theodore - Harris
# Drop The Mirror (EP Version) : 25 Jayden - Graves
# Shook Ones pt. 2 : 14 Theodore - Harris
# Pretendo Hablarte : 25 Jayden - Graves
# Bring Me To Life : 25 Jayden - Graves
# Clear Blue Water : 25 Jayden - Graves
# You're The One : 88 Mohammad - Rodriguez
# Lord Xenu : 88 Mohammad - Rodriguez
# Take Me To The River : 25 Jayden - Graves
# Flat Beat : 25 Jayden - Graves
# Never Too Far : 25 Jayden - Graves
# Day 'N' Nite : 25 Jayden - Graves
# El Hombre : 25 Jayden - Graves
# Geek In The Pink [Phil Tan Remix] : 25 Jayden - Graves
# You're The One : 25 Jayden - Graves
# I Second That Emotion : 25 Jayden - Graves
# Your Hand In Mine : 7 Adelyn - Jordan
# White Lies (Dave Spoon Remix) : 24 Layla - Griffin
# God of Justice : 24 Layla - Griffin
# I'll Meet You Halfway : 24 Layla - Griffin
# Crack The Shutters : 24 Layla - Griffin
# Darwin : 24 Layla - Griffin
# The Quest : 24 Layla - Griffin
# And Pray For Me : 24 Layla - Griffin
# Noc... : 24 Layla - Griffin
# Your Visits Are Getting Shorter : 24 Layla - Griffin
# At Last : 24 Layla - Griffin
# Orange TrÃÂ¤gt Nur Die MÃÂ¼llabfuhr (Go West) : 24 Layla - Griffin
# Who Can Compare : 24 Layla - Griffin
# Hecho En Buenos Aires : 24 Layla - Griffin
# Mariposa traicionera : 24 Layla - Griffin
# Feels Like Home : 24 Layla - Griffin
# Come To Me : 24 Layla - Griffin
# Hochmah (Interlude) : 24 Layla - Griffin
# Walk Like A Woman (Album Version) : 24 Layla - Griffin
# Girls Girls Girls : 24 Layla - Griffin
# Taxi  (LP Version) : 24 Layla - Griffin
# The Middle : 24 Layla - Griffin
# Profile (Album Version) : 24 Layla - Griffin
# Undo : 24 Layla - Griffin
# I Have A Boyfriend : 24 Layla - Griffin
# Dangerously In Love : 24 Layla - Griffin
# More Than This : 24 Layla - Griffin
# Nach dir kommt nichts : 24 Layla - Griffin
# One I Love : 24 Layla - Griffin
# Just Between You And Me (Remastered LP Version) : 66 Kevin - Arellano
# One Brick : 24 Layla - Griffin
# Drunkship Of Lanterns : 24 Layla - Griffin
# Kaiken se kÃÂ¤rsii : 24 Layla - Griffin
# Use Somebody : 24 Layla - Griffin
# Shots : 24 Layla - Griffin
# EverybodyÃÂ´s Free : 37 Jordan - Hicks
# Scratch That Itch (LP Version) : 24 Layla - Griffin
# Revelry : 24 Layla - Griffin
# Rock Star : 24 Layla - Griffin
# Gears : 15 Lily - Koch
# The Lucky Ones : 24 Layla - Griffin
# Just Dance : 24 Layla - Griffin
# In The End (Album Version) : 15 Lily - Koch
# Moving Forward (feat. Late_ M.E.N.I.S. & Caper) : 15 Lily - Koch
# I Am The Dog : 24 Layla - Griffin
# Too Young : 24 Layla - Griffin
# A Year Or Two : 15 Lily - Koch
# D.A.N.C.E. [Live Version] : 24 Layla - Griffin
# Joe's Head : 15 Lily - Koch
# City On The Edge Of Forever : 24 Layla - Griffin
# Resistance : 15 Lily - Koch
# Te LastimÃÂ© : 24 Layla - Griffin
# Yellow Zone : 15 Lily - Koch
# Indestructible : 24 Layla - Griffin
# Dick In A Box : 15 Lily - Koch
# What If I Do? : 24 Layla - Griffin
# I'm In Miami Bitch : 15 Lily - Koch
# Shattered By Broken Dreams : 15 Lily - Koch
# Hollywood Kids : 24 Layla - Griffin
# Don't : 24 Layla - Griffin
# Shiver : 24 Layla - Griffin
# Yellow : 24 Layla - Griffin
# Crazier : 24 Layla - Griffin
# Waitin' On A Woman : 10 Sylvie - Cruz
# El Presidiario : 24 Layla - Griffin
# Be My Guest : 24 Layla - Griffin
# A Lack of Common Sense : 24 Layla - Griffin
# Undo : 24 Layla - Griffin
# Last Day Of Magic : 24 Layla - Griffin
# Just Dance : 24 Layla - Griffin
# Flashing Lights : 24 Layla - Griffin
# Noise : 24 Layla - Griffin
# Girl Money : 24 Layla - Griffin
# World Famous : 24 Layla - Griffin
# All That You Are (Instrumental) : 24 Layla - Griffin
# Double Yellow Lines : 24 Layla - Griffin
# (You Drive Me) Crazy (The Stop Remix!) : 80 Tegan - Levine
# Architect Of Love : 24 Layla - Griffin
# Beach Party : 80 Tegan - Levine
# Stronger : 24 Layla - Griffin
# Good Life : 80 Tegan - Levine
# Baby's A Rock 'N' Roller (Album Version) : 80 Tegan - Levine
# Heartspark Dollarsign : 24 Layla - Griffin
# You Can't Hurry Love : 24 Layla - Griffin
# Where Do You Go : 24 Layla - Griffin
# You're The One : 24 Layla - Griffin
# West One (Shine On Me) : 24 Layla - Griffin
# The Wait (Feat. David Autokratz) : 24 Layla - Griffin
# Hard Headed Woman : 24 Layla - Griffin
# Love Shack : 24 Layla - Griffin
# A'rabti : 24 Layla - Griffin
# Unwell (Album Version) : 24 Layla - Griffin
# Personal Jesus : 24 Layla - Griffin
# The Light & The Glass : 24 Layla - Griffin
# Elusive Butterfly : 24 Layla - Griffin
# Astral Romance : 24 Layla - Griffin
# Timebomb (LP Version) : 24 Layla - Griffin
# BedRock (Radio Edit) (feat.Lloyd) : 24 Layla - Griffin
# The Eldar (Remastered) : 24 Layla - Griffin
# Made Of Scars (Album Version) : 24 Layla - Griffin
# Face To Face : 24 Layla - Griffin
# Les hommes que j'aime : 24 Layla - Griffin
# Footnotes : 26 Ryan - Smith
# No Te Rindas : 24 Layla - Griffin
# Master Of Puppets : 24 Layla - Griffin
# Nobody Noticed The Fire : 24 Layla - Griffin
# Big Calm : 58 Emily - Benson
# Flatten the Hay : 58 Emily - Benson
# Let's Make Love And Listen To Death From Above [Dan Carey Mix] (remastered album version) : 24 Layla - Griffin
# Elevator Love Letter : 58 Emily - Benson
# Tighten Up : 24 Layla - Griffin
# Happy Endings : 75 Joseph - Gutierrez
# The Bomb (Little Louie Vega Bonus) : 41 Brayden - Clark
# Love Story : 41 Brayden - Clark
# El Rey : 41 Brayden - Clark
# When The Lights Go Out : 70 Jaleah - Hayes
# Sixteen Tons : 70 Jaleah - Hayes
# Gardenhead / Leave Me Alone : 70 Jaleah - Hayes
# Through Your Hands (Album Version) : 70 Jaleah - Hayes
# MODUL 23 : 70 Jaleah - Hayes
# Explanation : 49 Chloe - Cuevas
# Arc Of Time (time Code) (Album Version) : 70 Jaleah - Hayes
# OMG : 70 Jaleah - Hayes
# Make You Love Me : 49 Chloe - Cuevas
# Sugar Ray (LP Version) : 49 Chloe - Cuevas
# Ming Tran : 49 Chloe - Cuevas
# Step Through The Door : 70 Jaleah - Hayes
# Johnny_ I Hardly Knew Ya : 49 Chloe - Cuevas
# T.I.M.E.B.O.M.B. : 70 Jaleah - Hayes
# Little Smirk : 70 Jaleah - Hayes
# Do The Panic : 70 Jaleah - Hayes
# Behind The Sea [Live In Chicago] : 70 Jaleah - Hayes
# Windmill Wedding : 70 Jaleah - Hayes
# American Idiot [feat. Green Day & The Cast Of American Idiot] (Album Version) : 70 Jaleah - Hayes
# Nothing Can Come Between Us : 70 Jaleah - Hayes
# Holes To Heaven : 24 Layla - Griffin
# Boys Will Be Boys : 24 Layla - Griffin
# Creep (Explicit) : 24 Layla - Griffin
# Ocean View : 24 Layla - Griffin
# Tive Sim : 24 Layla - Griffin
# Incentive (Bonus Track) : 24 Layla - Griffin
# A Little Bit Of Love : 24 Layla - Griffin
# Black & Gold : 24 Layla - Griffin
# June 9th : 24 Layla - Griffin
# What Now My Love (LP Version) : 24 Layla - Griffin
# Baker's Blue Jay Yarn : 24 Layla - Griffin
# Please_ Before I Go : 24 Layla - Griffin
# Freeze Up : 24 Layla - Griffin
# The Calculation (Album Version) : 35 Molly - Taylor
# Revolution Deathsquad (Album Version) : 52 Theodore - Smith
# ReprÃÂ©sente : 35 Molly - Taylor
# One Woman Man : 52 Theodore - Smith
# Somebody Better : 88 Mohammad - Rodriguez
# Llore Por Tu Amor : 88 Mohammad - Rodriguez
# Itchy Feet : 88 Mohammad - Rodriguez
# Diyala : 88 Mohammad - Rodriguez
# Here In The Middle : 88 Mohammad - Rodriguez
# Droomland (duet met Paul de Leeuw) : 54 Kaleb - Cook
# Autumn Leaves : 88 Mohammad - Rodriguez
# Shiver : 54 Kaleb - Cook
# Walk : 88 Mohammad - Rodriguez
# Corrido de Boxeo : 42 Harper - Barrett
# Runnin' Down A Dream : 42 Harper - Barrett
# Citizen Of The Planet (Album Version) : 42 Harper - Barrett
# Freakin' Out : 42 Harper - Barrett
# (They Long To Be) Close To You : 42 Harper - Barrett
# Blue Eyed Pop : 42 Harper - Barrett
# Mourning Morning : 60 Devin - Larson
# Lodi : 42 Harper - Barrett
# To The Ground : 60 Devin - Larson
# I'm Yours (Album Version) : 42 Harper - Barrett
# It's Tricky : 60 Devin - Larson
# Natural High : 42 Harper - Barrett
# Waiting : 60 Devin - Larson
# Paper Planes : 42 Harper - Barrett
# Clocks : 44 Aleena - Kirby
# Have A Nice Day : 44 Aleena - Kirby
# Alive (2006 Remastered Album Version) : 44 Aleena - Kirby
# Plans (Replanned by Mogwai) : 44 Aleena - Kirby
# Pa Pa Pa : 44 Aleena - Kirby
# Lots More Stairs : 44 Aleena - Kirby
# Ecoute Ce Scratch : 44 Aleena - Kirby
# Tierra Tradicional : 44 Aleena - Kirby
# Simmons Incorporated : 44 Aleena - Kirby
# I'm Goin' Away : 67 Colm - Santana
# In The Fade : 44 Aleena - Kirby
# Strawberry AndrÃÂ© (Album Version) : 67 Colm - Santana
# Eyes As Candles : 44 Aleena - Kirby
# Let's Get It Started : 67 Colm - Santana
# Ca plane pour moi : 67 Colm - Santana
# Strange Brew : 67 Colm - Santana
# A Message : 67 Colm - Santana
# Sweat the Battle Before the Battle Sweats You (Album Version) : 67 Colm - Santana
# Of Wolf And Man : 62 Connar - Moreno
# Tape Song : 62 Connar - Moreno
# The Pretender : 62 Connar - Moreno
# Eyen [Chosen by fans on Warp20.net] : 62 Connar - Moreno
# It's New To Me : 14 Theodore - Harris
# Make You Smile : 26 Ryan - Smith
# I May Never Find : 16 Rylan - George
# Black Horse And The Cherry Tree (Radio Version) : 26 Ryan - Smith
# Kids In America : 16 Rylan - George
# Black Heart Inertia : 26 Ryan - Smith
# Black & Blue : 80 Tegan - Levine
# Sala De RecepÃÂ§ÃÂ£o : 80 Tegan - Levine
# Commander In Thief : 80 Tegan - Levine
# Woman : 80 Tegan - Levine
# Wagon Wheel : 80 Tegan - Levine
# Debbie : 80 Tegan - Levine
# I Think I'll Live : 80 Tegan - Levine
# La Derrota de Un Don Juan : 80 Tegan - Levine
# Le Courage Des Oiseaux : 80 Tegan - Levine
# Run With The Blind : 80 Tegan - Levine
# I Love You So Much It Hurts : 80 Tegan - Levine
# A Little Death Around the Eyes : 80 Tegan - Levine
# Thinking Of You : 80 Tegan - Levine
# You Love Me Anyway (Album) : 35 Molly - Taylor
# Torches : 35 Molly - Taylor
# Wavin'  Flag : 35 Molly - Taylor
# Holiday : 26 Ryan - Smith
# Empire State Of Mind (Part II) Broken Down : 26 Ryan - Smith

# %%
## TO-DO: Add in the SELECT statement to verify the data was entered into the table        
select_query_3 = """ SELECT firstname, lastname
                    FROM user_details
                    WHERE song = %s 
                    """

try:
    rows = session.execute(select_query_3, ('All Hands Against His Own', ))
    
    for row in rows:
        print("User First Name: "+row.firstname, "\nUser Second Name: "+row.lastname)
              
except Exception as e:
    print(e)
# Out:
# User First Name: Jacqueline
# User Second Name: Lynch
# User First Name: Tegan
# User Second Name: Levine
# User First Name: Sara
# User Second Name: Johnson

# %% [markdown]
# ### Drop the tables before closing out the sessions

# %%
## TO-DO: Drop the table before closing out the sessions
session.execute("DROP TABLE IF EXISTS song_details")
session.execute("DROP TABLE IF EXISTS artist_details")
session.execute("DROP TABLE IF EXISTS user_details")

# %% [markdown]
# ### Close the session and cluster connection¶

# %%
session.shutdown()
cluster.shutdown()
